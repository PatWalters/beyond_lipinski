# %%
import chembl_downloader
import pandas as pd
from rdkit import Chem
from rdkit.Chem.MolStandardize import rdMolStandardize
from tqdm import tqdm

# %%
def standardize(mol):
    # follows the steps in
    # https://github.com/greglandrum/RSC_OpenScience_Standardization_202104/blob/main/MolStandardize%20pieces.ipynb
    # as described **excellently** (by Greg) in
    # https://www.youtube.com/watch?v=eWTApNX8dJQ
     
    # removeHs, disconnect metal atoms, normalize the molecule, reionize the molecule
    clean_mol = rdMolStandardize.Cleanup(mol) 
     
    # if many fragments, get the "parent" (the actual mol we are interested in) 
    parent_clean_mol = rdMolStandardize.FragmentParent(clean_mol)
         
    # try to neutralize molecule
    uncharger = rdMolStandardize.Uncharger() # annoying, but necessary as no convenience method exists
    uncharged_parent_clean_mol = uncharger.uncharge(parent_clean_mol)
     
    # note that no attempt is made at reionization at this step
    # nor at ionization at some pH (rdkit has no pKa caculator)
    # the main aim to to represent all molecules from different sources
    # in a (single) standard way, for use in ML, catalogue, etc.
     
    te = rdMolStandardize.TautomerEnumerator() # idem
    taut_uncharged_parent_clean_mol = te.Canonicalize(uncharged_parent_clean_mol)
     
    return taut_uncharged_parent_clean_mol

def standardize_and_catch(mol):
    try:
        std_mol = standardize(mol)
    except:
        std_mol = None
    return std_mol

def add_analysis_columns(df,smiles_col,year_col,name_col):
    # add an RDKit molecule column
    df['mol'] = df[smiles_col].progress_apply(Chem.MolFromSmiles)
    # standardize the molecule
    df['std_mol'] = df.mol.progress_apply(standardize_and_catch)
    # generate a standard smiles, useful for duplicate removal
    df['std_smiles'] = df.std_mol.progress_apply(Chem.MolToSmiles)
    # add a fingerprint column
    df['fp'] = df.std_mol.progress_apply(uru.mol2morgan_fp)
    # add a year with a standard name
    df['year'] = df[year_col]
    # clean the name and create a column
    df['drug_name'] = [x.strip().upper() for x in df[name_col]]

# %%
tqdm.pandas()

# %%
chembl_drug_query = """select cs.canonical_smiles, md.*
       from molecule_dictionary md
         join compound_structures cs on md.molregno = cs.molregno
         where max_phase == 4"""

# %%
chembl_drug_df = chembl_downloader.query(chembl_drug_query)

# %%
add_analysis_columns(chembl_drug_df,"canonical_smiles","first_approval","pref_name")
# Out:
# 100%|████████████████████████████████████████████████████████████| 3447/3447 [00:00<00:00, 5378.05it/s]
#   1%|▉                                                              | 49/3447 [00:00<00:32, 103.39it/s][15:37:47] Can't kekulize mol.  Unkekulized atoms: 4 9
#   4%|██▎                                                           | 127/3447 [00:01<00:26, 126.25it/s][15:37:48] Can't kekulize mol.  Unkekulized atoms: 3 7
#  13%|████████▏                                                     | 455/3447 [00:03<00:18, 164.35it/s][15:37:52] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  15%|█████████▏                                                     | 503/3447 [00:05<01:10, 41.61it/s][15:37:53] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  17%|██████████▋                                                    | 588/3447 [00:06<00:35, 79.52it/s][15:37:55] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
# [15:37:56] Tautomer enumeration stopped at 974 tautomers: max transforms reached
#  18%|███████████▌                                                   | 634/3447 [00:09<01:32, 30.45it/s][15:37:58] Tautomer enumeration stopped at 722 tautomers: max transforms reached
#  19%|███████████▊                                                   | 645/3447 [00:11<02:26, 19.18it/s][15:37:58] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  21%|█████████████▎                                                 | 726/3447 [00:12<00:40, 67.20it/s][15:37:59] Can't kekulize mol.  Unkekulized atoms: 2 6 7
# [15:38:00] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  23%|██████████████▍                                                | 787/3447 [00:13<00:45, 58.39it/s][15:38:01] Tautomer enumeration stopped at 301 tautomers: max transforms reached
#  24%|███████████████▍                                               | 842/3447 [00:14<00:30, 85.10it/s][15:38:01] Tautomer enumeration stopped at 375 tautomers: max transforms reached
# [15:38:02] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  26%|████████████████▏                                              | 883/3447 [00:15<00:45, 56.45it/s][15:38:03] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  28%|█████████████████▍                                             | 956/3447 [00:17<01:16, 32.65it/s][15:38:04] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
# [15:38:05] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
# [15:38:06] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  28%|█████████████████▋                                             | 965/3447 [00:19<02:36, 15.88it/s][15:38:06] Tautomer enumeration stopped at 245 tautomers: max transforms reached
#  29%|██████████████████▏                                           | 1012/3447 [00:19<00:58, 41.92it/s][15:38:07] Tautomer enumeration stopped at 604 tautomers: max transforms reached
#  31%|███████████████████                                           | 1057/3447 [00:20<00:45, 52.40it/s][15:38:08] Tautomer enumeration stopped at 738 tautomers: max transforms reached
#  31%|███████████████████▍                                          | 1080/3447 [00:21<00:53, 43.85it/s][15:38:09] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  32%|███████████████████▋                                          | 1097/3447 [00:22<01:11, 32.72it/s][15:38:10] Tautomer enumeration stopped at 383 tautomers: max transforms reached
#  32%|████████████████████▏                                         | 1119/3447 [00:23<01:23, 27.88it/s][15:38:11] Tautomer enumeration stopped at 376 tautomers: max transforms reached
#  33%|████████████████████▎                                         | 1128/3447 [00:23<01:37, 23.83it/s][15:38:11] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  33%|████████████████████▍                                         | 1138/3447 [00:24<01:53, 20.40it/s][15:38:12] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  33%|████████████████████▌                                         | 1142/3447 [00:25<02:30, 15.29it/s][15:38:12] Tautomer enumeration stopped at 333 tautomers: max transforms reached
#  33%|████████████████████▌                                         | 1145/3447 [00:25<02:42, 14.21it/s][15:38:13] Tautomer enumeration stopped at 276 tautomers: max transforms reached
#  33%|████████████████████▋                                         | 1147/3447 [00:25<03:03, 12.54it/s][15:38:13] Tautomer enumeration stopped at 476 tautomers: max transforms reached
#  34%|████████████████████▊                                         | 1158/3447 [00:26<02:23, 15.98it/s][15:38:13] Tautomer enumeration stopped at 160 tautomers: max transforms reached
#  34%|████████████████████▉                                         | 1163/3447 [00:26<03:14, 11.74it/s][15:38:14] Tautomer enumeration stopped at 162 tautomers: max transforms reached
# [15:38:14] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  34%|█████████████████████▏                                        | 1178/3447 [00:27<02:23, 15.86it/s][15:38:16] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  35%|█████████████████████▍                                        | 1194/3447 [00:29<03:21, 11.20it/s][15:38:17] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  35%|█████████████████████▌                                        | 1198/3447 [00:30<03:41, 10.16it/s][15:38:18] Tautomer enumeration stopped at 336 tautomers: max transforms reached
#  35%|█████████████████████▋                                        | 1203/3447 [00:30<03:44, 10.00it/s][15:38:18] Tautomer enumeration stopped at 287 tautomers: max transforms reached
#  35%|█████████████████████▋                                        | 1207/3447 [00:31<03:55,  9.51it/s][15:38:19] Tautomer enumeration stopped at 403 tautomers: max transforms reached
#  37%|██████████████████████▊                                       | 1268/3447 [00:32<00:36, 59.68it/s][15:38:20] Tautomer enumeration stopped at 160 tautomers: max transforms reached
#  37%|███████████████████████                                       | 1280/3447 [00:32<00:58, 36.91it/s][15:38:20] Can't kekulize mol.  Unkekulized atoms: 4 8
#  38%|███████████████████████▎                                      | 1294/3447 [00:33<00:45, 47.18it/s][15:38:21] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
# [15:38:22] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  38%|███████████████████████▋                                      | 1317/3447 [00:35<01:50, 19.19it/s][15:38:22] Tautomer enumeration stopped at 132 tautomers: max transforms reached
#  38%|███████████████████████▊                                      | 1323/3447 [00:35<01:52, 18.83it/s][15:38:24] Tautomer enumeration stopped at 975 tautomers: max transforms reached
#  40%|████████████████████████▊                                     | 1379/3447 [00:37<00:42, 49.15it/s][15:38:25] Tautomer enumeration stopped at 132 tautomers: max transforms reached
#  40%|█████████████████████████                                     | 1390/3447 [00:37<00:51, 40.25it/s][15:38:25] Tautomer enumeration stopped at 160 tautomers: max transforms reached
# [15:38:33] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  41%|█████████████████████████▎                                    | 1410/3447 [00:46<06:07,  5.55it/s][15:38:34] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  41%|█████████████████████████▍                                    | 1416/3447 [00:47<06:13,  5.44it/s][15:38:35] Tautomer enumeration stopped at 289 tautomers: max transforms reached
#  41%|█████████████████████████▌                                    | 1421/3447 [00:48<05:37,  6.01it/s][15:38:35] Can't kekulize mol.  Unkekulized atoms: 3 7
# [15:38:35] Tautomer enumeration stopped at 162 tautomers: max transforms reached
#  42%|██████████████████████████▎                                   | 1461/3447 [00:50<03:09, 10.48it/s][15:38:37] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
# [15:38:39] Tautomer enumeration stopped at 874 tautomers: max transforms reached
# [15:38:39] Tautomer enumeration stopped at 376 tautomers: max transforms reached
#  43%|██████████████████████████▎                                   | 1465/3447 [00:52<04:45,  6.93it/s][15:38:41] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  43%|██████████████████████████▍                                   | 1472/3447 [00:54<05:47,  5.68it/s][15:38:43] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  43%|██████████████████████████▋                                   | 1486/3447 [00:56<04:36,  7.09it/s][15:38:45] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
# [15:38:46] Tautomer enumeration stopped at 219 tautomers: max transforms reached
# [15:38:47] Tautomer enumeration stopped at 759 tautomers: max transforms reached
#  43%|██████████████████████████▊                                   | 1490/3447 [01:00<10:41,  3.05it/s][15:38:48] Can't kekulize mol.  Unkekulized atoms: 7
#  45%|████████████████████████████▏                                 | 1565/3447 [01:01<01:09, 27.18it/s][15:38:49] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#
Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
# [15:39:20] Can't kekulize mol.  Unkekulized atoms: 6 8 9 12 13 15
#  69%|██████████████████████████████████████████▊                   | 2382/3447 [01:33<00:24, 44.20it/s][15:39:20] Can't kekulize mol.  Unkekulized atoms: 7
#  69%|███████████████████████████████████████████                   | 2393/3447 [01:33<00:27, 38.25it/s][15:39:21] Tautomer enumeration stopped at 257 tautomers: max transforms reached
#  70%|███████████████████████████████████████████▏                  | 2402/3447 [01:33<00:30, 33.72it/s][15:39:21] Tautomer enumeration stopped at 219 tautomers: max transforms reached
#  70%|███████████████████████████████████████████▎                  | 2409/3447 [01:34<00:35, 29.22it/s][15:39:22] Tautomer enumeration stopped at 336 tautomers: max transforms reached
#  70%|███████████████████████████████████████████▍                  | 2415/3447 [01:34<00:52, 19.67it/s][15:39:23] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  72%|████████████████████████████████████████████▎                 | 2467/3447 [01:37<00:29, 33.52it/s][15:39:24] Can't kekulize mol.  Unkekulized atoms: 3 10
# [15:39:24] Can't kekulize mol.  Unkekulized atoms: 3 10
#  73%|█████████████████████████████████████████████▎                | 2521/3447 [01:37<00:13, 71.11it/s][15:39:24] Can't kekulize mol.  Unkekulized atoms: 2 12
#  74%|█████████████████████████████████████████████▋                | 2541/3447 [01:37<00:09, 91.05it/s][15:39:25] Tautomer enumeration stopped at 160 tautomers: max transforms reached
# [15:39:25] Tautomer enumeration stopped at 257 tautomers: max transforms reached
#  75%|██████████████████████████████████████████████▋               | 2594/3447 [01:38<00:10, 77.78it/s][15:39:27] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
# [15:39:27] Tautomer enumeration stopped at 276 tautomers: max transforms reached
#  77%|███████████████████████████████████████████████▌              | 2645/3447 [01:40<00:20, 38.75it/s][15:39:28] Tautomer enumeration stopped at 219 tautomers: max transforms reached
#  77%|███████████████████████████████████████████████▊              | 2659/3447 [01:41<00:21, 36.05it/s][15:39:28] Tautomer enumeration stopped at 219 tautomers: max transforms reached
#  77%|████████████████████████████████████████████████              | 2670/3447 [01:41<00:22, 33.86it/s][15:39:29] Tautomer enumeration stopped at 365 tautomers: max transforms reached
#  78%|████████████████████████████████████████████████▏             | 2679/3447 [01:42<00:26, 28.66it/s][15:39:29] Tautomer enumeration stopped at 229 tautomers: max transforms reached
#  78%|████████████████████████████████████████████████▌             | 2698/3447 [01:42<00:23, 32.00it/s][15:39:30] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  78%|████████████████████████████████████████████████▌             | 2703/3447 [01:43<00:48, 15.36it/s][15:39:31] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
# [15:39:32] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  79%|████████████████████████████████████████████████▉             | 2720/3447 [01:45<00:57, 12.57it/s][15:39:33] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  80%|█████████████████████████████████████████████████▎            | 2743/3447 [01:48<01:10,  9.96it/s][15:39:35] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
# [15:39:36] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  80%|█████████████████████████████████████████████████▌            | 2753/3447 [01:51<02:05,  5.51it/s] tautomers: max tautomers reachedtopped at 1000
# [15:39:39] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  80%|█████████████████████████████████████████████████▋            | 2759/3447 [01:52<02:06,  5.42it/s][15:39:40] Tautomer enumeration stopped at 276 tautomers: max transforms reached
#  80%|█████████████████████████████████████████████████▋            | 2763/3447 [01:52<01:50,  6.17it/s][15:39:40] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  80%|█████████████████████████████████████████████████▊            | 2768/3447 [01:54<01:58,  5.72it/s][15:39:41] Tautomer enumeration stopped at 275 tautomers: max transforms reached
#  80%|█████████████████████████████████████████████████▉            | 2773/3447 [01:54<01:36,  6.96it/s][15:39:44] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  81%|██████████████████████████████████████████████████▏           | 2791/3447 [01:59<02:28,  4.42it/s][15:39:46] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  82%|██████████████████████████████████████████████████▋           | 2815/3447 [02:00<01:03,  9.89it/s][15:39:47] Tautomer enumeration stopped at 403 tautomers: max transforms reached
#  84%|████████████████████████████████████████████████████          | 2895/3447 [02:00<00:07, 69.37it/s][15:39:48] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
# [15:39:48] Can't kekulize mol.  Unkekulized atoms: 23 27
#  85%|████████████████████████████████████████████████████▊         | 2939/3447 [02:05<00:34, 14.88it/s][15:39:53] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  86%|█████████████████████████████████████████████████████▏        | 2955/3447 [02:10<01:10,  7.00it/s]1000 tautomers: max tautomers reacheded at
# [15:39:58] Tautomer enumeration stopped at 132 tautomers: max transforms reached
#  86%|█████████████████████████████████████████████████████▍        | 2968/3447 [02:12<01:03,  7.50it/s]705 tautomers: max transforms reacheded at
#  86%|█████████████████████████████████████████████████████▍        | 2971/3447 [02:12<00:59,  7.98it/s][15:40:00] Tautomer enumeration stopped at 263 tautomers: max transforms reached
#  86%|█████████████████████████████████████████████████████▌        | 2978/3447 [02:12<00:49,  9.52it/s][15:40:00] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  86%|█████████████████████████████████████████████████████▌        | 2981/3447 [02:13<00:59,  7.90it/s][15:40:01] Tautomer enumeration stopped at 892 tautomers: max transforms reached
#  87%|█████████████████████████████████████████████████████▋        | 2983/3447 [02:14<01:09,  6.63it/s][15:40:02] Tautomer enumeration stopped at 974 tautomers: max transforms reached
#  87%|█████████████████████████████████████████████████████▋        | 2985/3447 [02:15<01:42,  4.50it/s][15:40:03] Tautomer enumeration stopped at 365 tautomers: max transforms reached
#  87%|█████████████████████████████████████████████████████▋        | 2986/3447 [02:15<01:53,  4.05it/s][15:40:10] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  87%|█████████████████████████████████████████████████████▊        | 2990/3447 [02:23<07:03,  1.08it/s][15:40:11] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  87%|█████████████████████████████████████████████████████▉        | 2998/3447 [02:25<03:56,  1.90it/s][15:40:12] Tautomer enumeration stopped at 892 tautomers: max transforms reached
#  88%|██████████████████████████████████████████████████████▎       | 3019/3447 [02:25<00:52,  8.13it/s][15:40:13] Tautomer enumeration stopped at 162 tautomers: max transforms reached
# [15:40:13] Tautomer enumeration stopped at 333 tautomers: max transforms reached
#  88%|██████████████████████████████████████████████████████▌       | 3032/3447 [02:26<00:35, 11.64it/s] tautomers: max transforms reachedopped at 340
# [15:40:14] Tautomer enumeration stopped at 340 tautomers: max transforms reached
#  89%|██████████████████████████████████████████████████████▉       | 3055/3447 [02:27<00:17, 21.90it/s][15:40:16] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#
Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  99%|█████████████████████████████████████████████████████████████▍| 3419/3447 [03:01<00:03,  7.97it/s][15:40:49] Can't kekulize mol.  Unkekulized atoms: 23 27
# [15:40:50] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
#  99%|█████████████████████████████████████████████████████████████▋| 3427/3447 [03:04<00:04,  4.36it/s][15:40:51] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
# 100%|█████████████████████████████████████████████████████████████▊| 3436/3447 [03:04<00:01,  7.28it/s][15:40:53] Tautomer enumeration stopped at 1000 tautomers: max tautomers reached
# 100%|██████████████████████████████████████████████████████████████| 3447/3447 [03:06<00:00, 18.46it/s]
#   2%|█▏                                                            | 64/3447 [00:00<00:00, 9673.35it/s]
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 add_analysis_columns(chembl_drug_df,"canonical_smiles","first_approval","pref_name")
#
# Cell In [13], line 40, in add_analysis_columns(df, smiles_col, year_col, name_col)
#      38 df['std_mol'] = df.mol.progress_apply(standardize_and_catch)
#      39 # generate a standard smiles, useful for duplicate removal
# ---> 40 df['std_smiles'] = df.std_mol.progress_apply(Chem.MolToSmiles)
#      41 # add a fingerprint column
#      42 df['fp'] = df.std_mol.progress_apply(uru.mol2morgan_fp)
#
# File ~/opt/anaconda3/envs/rdkit_2022_09/lib/python3.10/site-packages/tqdm/std.py:814, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     811 # Apply the provided function (in **kwargs)
#     812 # on the df using our wrapper (which provides bar updating)
#     813 try:
# --> 814     return getattr(df, df_function)(wrapper, **kwargs)
#     815 finally:
#     816     t.close()
#
# File ~/opt/anaconda3/envs/rdkit_2022_09/lib/python3.10/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/opt/anaconda3/envs/rdkit_2022_09/lib/python3.10/site-packages/pandas/core/apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# -> 1105 return self.apply_standard()
#
# File ~/opt/anaconda3/envs/rdkit_2022_09/lib/python3.10/site-packages/pandas/core/apply.py:1156, in SeriesApply.apply_standard(self)
#    1154     else:
#    1155         values = obj.astype(object)._values
# -> 1156         mapped = lib.map_infer(
#    1157             values,
#    1158             f,
#    1159             convert=self.convert_dtype,
#    1160         )
#    1162 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1163     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1164     #  See also GH#25959 regarding EA support
#    1165     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/opt/anaconda3/envs/rdkit_2022_09/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2918, in pandas._libs.lib.map_infer()
#
# File ~/opt/anaconda3/envs/rdkit_2022_09/lib/python3.10/site-packages/tqdm/std.py:809, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     803 def wrapper(*args, **kwargs):
#     804     # update tbar correctly
#     805     # it seems `pandas apply` calls `func` twice
#     806     # on the first column/row to decide whether it can
#     807     # take a fast or slow code path; so stop when t.total==t.n
#     808     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 809     return func(*args, **kwargs)
#
# ArgumentError: Python argument types in
#     rdkit.Chem.rdmolfiles.MolToSmiles(NoneType)
# did not match C++ signature:
#     MolToSmiles(RDKit::ROMol mol, bool isomericSmiles=True, bool kekuleSmiles=False, int rootedAtAtom=-1, bool canonical=True, bool allBondsExplicit=False, bool allHsExplicit=False, bool doRandom=False)
#     MolToSmiles(RDKit::ROMol mol, RDKit::SmilesWriteParams params)

# %%
paper_df = pd.read_csv("data/41570_2022_451_MOESM2_ESM.csv")

# %%
paper_df
# Out:
#               NAME  APPROVAL_YEAR DRUG_UID  \
# 0     Daridorexant           2022  DB15031
# 1     Nirmatrelvir           2022  DB16691
# 2       Pacritinib           2022  DB11697
# 3      Abrocitinib           2022  DB14973
# 4        Mitapivat           2022  DB16236
# ..             ...            ...      ...
# 112    Sarecycline           2018  DB12035
# 113    Tafenoquine           2018  DB06608
# 114   Benznidazole           2018  DB11989
# 115  Lusutrombopag           2018  DB13125
# 116    Tecovirimat           2018  DB12020
#
#                                                 SMILES       MW  N_HBA  N_HBD  \
# 0    COc1ccc(-n2nccn2)c(C(=O)N2CCCC2(C)c2nc3c(C)c(C...  450.921      8      1
# 1    CC(C)(C)C(NC(=O)C(F)(F)F)C(=O)N1CC2C(C1C(=O)NC...  499.526      9      3
# 2    C1=C/COCc2cc(ccc2OCCN2CCCC2)Nc2nccc(n2)-c2cccc...  472.579      7      1
# 3            CCCS(=O)(=O)NC1CC(N(C)c2ncnc3[nH]ccc23)C1  323.414      7      2
# 4    O=C(c1ccc(NS(=O)(=O)c2cccc3cccnc23)cc1)N1CCN(C...  450.553      7      1
# ..                                                 ...      ...    ...    ...
# 112  CON(C)Cc1ccc(O)c2c1CC1CC3C(N(C)C)C(O)=C(C(N)=O...  487.502     11      6
# 113  COc1cc(C)c2c(Oc3cccc(C(F)(F)F)c3)c(OC)cc(NC(C)...  463.493      6      3
# 114                O=C(Cn1ccnc1[N+](=O)[O-])NCc1ccccc1  260.249      7      1
# 115  CCCCCCOC(C)c1cccc(-c2csc(NC(=O)c3cc(Cl)c(/C=C(...  591.546      7      2
# 116  O=C(NN1C(=O)C2C3C=CC(C4CC34)C2C1=O)c1ccc(C(F)(...  376.329      5      1
#
#       LOGP  RO5_violations  FRACTION_CSP3  N_HEAVY  N_ROT_BONDS    TPSA  \
# 0    3.602               0          0.304       32            4   88.93
# 1    3.173               0          0.783       35            9  131.40
# 2    4.435               0          0.357       35            4   68.74
# 3    1.825               0          0.571       22            6   99.36
# 4    2.337               0          0.333       32            6   90.99
# ..     ...             ...            ...      ...          ...     ...
# 112  1.154               2          0.458       35            5  173.86
# 113  4.840               0          0.375       33           10   78.63
# 114  0.985               0          0.167       19            5   92.74
# 115  6.695               2          0.345       39           13  125.99
# 116  2.198               0          0.421       27            3   66.48
#
#      LOGD_74
# 0      3.530
# 1      3.130
# 2      2.912
# 3      1.816
# 4      2.164
# ..       ...
# 112   -1.757
# 113    2.054
# 114    0.985
# 115    3.496
# 116    2.198
#
# [117 rows x 14 columns]
